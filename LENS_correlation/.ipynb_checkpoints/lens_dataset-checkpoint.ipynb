# %%
# Load all libraries

import xarray as xr
import pathlib
from os import listdir
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
from matplotlib import gridspec
import matplotlib

# %%
import intake
from ecgtools import Builder
from ecgtools.parsers import parse_cmip6
from ecgtools.parsers.cesm import parse_cesm_timeseries
import pandas as pd 
import xarray as xr
import numpy as np
import itertools

# %% [markdown]
# # Catalog for CMIP6

# %%
filepathlist = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cmip6_lens/subdir_list.csv',\
                       header=None,names=['dirpaths']).values.tolist()

# Transform list of lists to list of strings
filepath=list(itertools.chain.from_iterable(filepathlist))

# %%
# Create the Builder
cat_builder = Builder(
    # Directory of Organized CMIP6 files 
    paths=filepath)

# Build the Catalog
catalog = cat_builder.build(parsing_func=parse_cmip6)
# Out:
# /data/keeling/a/mailes2/miniconda3/envs/paleoproj/lib/python3.10/site-packages/ecgtools/builder.py:204: UserWarning: Unable to parse 37 assets. A list of these assets can be found in `.invalid_assets` attribute.
#   ).clean_dataframe()

# %%
# Browse the catalog
catalog.df
# Out:
#      activity_id                                      branch_method  \
# 3           CMIP                                           standard
# 4           CMIP                                           standard
# 5           CMIP                                           standard
# 6           CMIP                                           standard
# 7           CMIP                                           standard
# ...          ...                                                ...
# 1401        CMIP  perturbations to atmospheric fields were appli...
# 1402        CMIP  perturbations to atmospheric fields were appli...
# 1403        CMIP  perturbations to atmospheric fields were appli...
# 1404        CMIP  perturbations to atmospheric fields were appli...
# 1405        CMIP  perturbations to atmospheric fields were appli...
#
#       branch_time_in_child  branch_time_in_parent  \
# 3                      0.0               164359.0
# 4                      0.0               164359.0
# 5                      0.0                    0.0
# 6                      0.0                18262.0
# 7                      0.0                36524.0
# ...                    ...                    ...
# 1401              674885.0               674885.0
# 1402              674885.0               674885.0
# 1403              674885.0               674885.0
# 1404              674885.0               674885.0
# 1405              674885.0               674885.0
#
#                                      experiment experiment_id frequency  \
# 3     all-forcing simulation of the recent past    historical       mon
# 4     all-forcing simulation of the recent past    historical       mon
# 5     all-forcing simulation of the recent past    historical       mon
# 6     all-forcing simulation of the recent past    historical       mon
# 7     all-forcing simulation of the recent past    historical       mon
# ...                                         ...           ...       ...
# 1401  all-forcing simulation of the recent past    historical       mon
# 1402  all-forcing simulation of the recent past    historical       mon
# 1403  all-forcing simulation of the recent past    historical       mon
# 1404  all-forcing simulation of the recent past    historical       mon
# 1405  all-forcing simulation of the recent past    historical       mon
#
#                                                    grid grid_label  \
# 3          native atmosphere N96 grid (144x192 latxlon)         gn
# 4          native atmosphere N96 grid (144x192 latxlon)         gn
# 5          native atmosphere N96 grid (144x192 latxlon)         gn
# 6          native atmosphere N96 grid (144x192 latxlon)         gn
# 7          native atmosphere N96 grid (144x192 latxlon)         gn
# ...                                                 ...        ...
# 1401  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1402  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1403  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1404  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1405  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
#
#      institution_id  ...        standard_name                     long_name  \
# 3      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 4      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 5      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 6      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 7      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# ...             ...  ...                  ...                           ...
# 1401            NCC  ...  surface_temperature           Surface Temperature
# 1402            NCC  ...  surface_temperature           Surface Temperature
# 1403            NCC  ...  surface_temperature           Surface Temperature
# 1404            NCC  ...  surface_temperature           Surface Temperature
# 1405            NCC  ...  surface_temperature           Surface Temperature
#
#      units vertical_levels init_year           start_time  \
# 3        K             1.0       NaN  1850-01-16 12:00:00
# 4        K             1.0       NaN  1950-01-16 12:00:00
# 5        K             1.0       NaN  1850-01-16 12:00:00
# 6        K             1.0       NaN  1850-01-16 12:00:00
# 7        K             1.0       NaN  1850-01-16 12:00:00
# ...    ...             ...       ...                  ...
# 1401     K             1.0       NaN  1850-01-16 12:00:00
# 1402     K             1.0       NaN  1850-01-16 12:00:00
# 1403     K             1.0       NaN  1850-01-16 12:00:00
# 1404     K             1.0       NaN  1850-01-16 12:00:00
# 1405     K             1.0       NaN  1850-01-16 12:00:00
#
#                  end_time                               time_range  \
# 3     1949-12-16 12:00:00  1850-01-16 12:00:00-1949-12-16 12:00:00
# 4     2014-12-16 12:00:00  1950-01-16 12:00:00-2014-12-16 12:00:00
# 5     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 6     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 7     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# ...                   ...                                      ...
# 1401  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1402  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1403  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1404  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1405  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
#
#                                                    path version
# 3     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 4     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 5     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 6     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 7     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# ...                                                 ...     ...
# 1401  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1402  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1403  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1404  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1405  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
#
# [1370 rows x 36 columns]

# %%
# Save the catalog as .csv 
catalog.df.to_csv('/data/keeling/a/cristi/a/esm_data/cmip6lens_catalog.csv', index=False)

# %% [markdown]
# # Catalog for CESM2

# %%
filepathlist_cesm = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cesm2_lens/subdir_list.csv',\
                       header=None,names=['dirpaths']).values.tolist()

# Transform list of lists to list of strings
filepath_cesm = list(itertools.chain.from_iterable(filepathlist_cesm))

# %%
# Create the Builder
cat_builder_cesm = Builder(
    # Directory of Organized CMIP6 files 
    paths=filepath_cesm)

# Build the Catalog
catalog_cesm = cat_builder_cesm.build(parsing_func=parse_cesm_timeseries)
# Out:
# /data/keeling/a/mailes2/miniconda3/envs/paleoproj/lib/python3.10/site-packages/ecgtools/builder.py:204: UserWarning: Unable to parse 3 assets. A list of these assets can be found in `.invalid_assets` attribute.
#   ).clean_dataframe()

# %%
# Browse the catalog
catalog_cesm.df
# Out:
#     component  stream                                   case member_id  \
# 1         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001       001
# 2         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001       001
# 3         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001       001
# 4         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001       001
# 5         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001       001
# ..        ...     ...                                    ...       ...
# 846       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010       010
# 847       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010       010
# 848       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010       010
# 849       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010       010
# 850       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010       010
#
#     variable start_time end_time     time_range                     long_name  \
# 1     TREFHT    1850-01  1859-12  185001-185912  Reference height temperature
# 2     TREFHT    1860-01  1869-12  186001-186912  Reference height temperature
# 3     TREFHT    1870-01  1879-12  187001-187912  Reference height temperature
# 4     TREFHT    1880-01  1889-12  188001-188912  Reference height temperature
# 5     TREFHT    1890-01  1899-12  189001-189912  Reference height temperature
# ..       ...        ...      ...            ...                           ...
# 846   TREFHT    1970-01  1979-12  197001-197912  Reference height temperature
# 847   TREFHT    1980-01  1989-12  198001-198912  Reference height temperature
# 848   TREFHT    1990-01  1999-12  199001-199912  Reference height temperature
# 849   TREFHT    2000-01  2009-12  200001-200912  Reference height temperature
# 850   TREFHT    2010-01  2014-12  201001-201412  Reference height temperature
#
#     units  vertical_levels frequency  \
# 1       K              1.0   month_1
# 2       K              1.0   month_1
# 3       K              1.0   month_1
# 4       K              1.0   month_1
# 5       K              1.0   month_1
# ..    ...              ...       ...
# 846     K              1.0   month_1
# 847     K              1.0   month_1
# 848     K              1.0   month_1
# 849     K              1.0   month_1
# 850     K              1.0   month_1
#
#                                                   path
# 1    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 2    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 3    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 4    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 5    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# ..                                                 ...
# 846  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 847  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 848  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 849  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 850  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
#
# [850 rows x 13 columns]

# %%
# Save the catalog as .csv 
catalog_cesm.df.to_csv('/data/keeling/a/cristi/a/esm_data/cesm2_lens_catalog.csv', index=False)

# %% [markdown]
# # Create Dataset!

# %% [markdown]
# ## CMIP6

# %%
cat = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cmip6lens_catalog.csv')
cat
# Out:
#      activity_id                                      branch_method  \
# 0           CMIP                                           standard
# 1           CMIP                                           standard
# 2           CMIP                                           standard
# 3           CMIP                                           standard
# 4           CMIP                                           standard
# ...          ...                                                ...
# 1365        CMIP  perturbations to atmospheric fields were appli...
# 1366        CMIP  perturbations to atmospheric fields were appli...
# 1367        CMIP  perturbations to atmospheric fields were appli...
# 1368        CMIP  perturbations to atmospheric fields were appli...
# 1369        CMIP  perturbations to atmospheric fields were appli...
#
#       branch_time_in_child  branch_time_in_parent  \
# 0                      0.0               164359.0
# 1                      0.0               164359.0
# 2                      0.0                    0.0
# 3                      0.0                18262.0
# 4                      0.0                36524.0
# ...                    ...                    ...
# 1365              674885.0               674885.0
# 1366              674885.0               674885.0
# 1367              674885.0               674885.0
# 1368              674885.0               674885.0
# 1369              674885.0               674885.0
#
#                                      experiment experiment_id frequency  \
# 0     all-forcing simulation of the recent past    historical       mon
# 1     all-forcing simulation of the recent past    historical       mon
# 2     all-forcing simulation of the recent past    historical       mon
# 3     all-forcing simulation of the recent past    historical       mon
# 4     all-forcing simulation of the recent past    historical       mon
# ...                                         ...           ...       ...
# 1365  all-forcing simulation of the recent past    historical       mon
# 1366  all-forcing simulation of the recent past    historical       mon
# 1367  all-forcing simulation of the recent past    historical       mon
# 1368  all-forcing simulation of the recent past    historical       mon
# 1369  all-forcing simulation of the recent past    historical       mon
#
#                                                    grid grid_label  \
# 0          native atmosphere N96 grid (144x192 latxlon)         gn
# 1          native atmosphere N96 grid (144x192 latxlon)         gn
# 2          native atmosphere N96 grid (144x192 latxlon)         gn
# 3          native atmosphere N96 grid (144x192 latxlon)         gn
# 4          native atmosphere N96 grid (144x192 latxlon)         gn
# ...                                                 ...        ...
# 1365  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1366  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1367  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1368  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
# 1369  finite-volume grid with 1.9x2.5 degree lat/lon...         gn
#
#      institution_id  ...        standard_name                     long_name  \
# 0      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 1      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 2      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 3      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# 4      CSIRO-ARCCSS  ...      air_temperature  Near-Surface Air Temperature
# ...             ...  ...                  ...                           ...
# 1365            NCC  ...  surface_temperature           Surface Temperature
# 1366            NCC  ...  surface_temperature           Surface Temperature
# 1367            NCC  ...  surface_temperature           Surface Temperature
# 1368            NCC  ...  surface_temperature           Surface Temperature
# 1369            NCC  ...  surface_temperature           Surface Temperature
#
#      units vertical_levels init_year           start_time  \
# 0        K             1.0       NaN  1850-01-16 12:00:00
# 1        K             1.0       NaN  1950-01-16 12:00:00
# 2        K             1.0       NaN  1850-01-16 12:00:00
# 3        K             1.0       NaN  1850-01-16 12:00:00
# 4        K             1.0       NaN  1850-01-16 12:00:00
# ...    ...             ...       ...                  ...
# 1365     K             1.0       NaN  1850-01-16 12:00:00
# 1366     K             1.0       NaN  1850-01-16 12:00:00
# 1367     K             1.0       NaN  1850-01-16 12:00:00
# 1368     K             1.0       NaN  1850-01-16 12:00:00
# 1369     K             1.0       NaN  1850-01-16 12:00:00
#
#                  end_time                               time_range  \
# 0     1949-12-16 12:00:00  1850-01-16 12:00:00-1949-12-16 12:00:00
# 1     2014-12-16 12:00:00  1950-01-16 12:00:00-2014-12-16 12:00:00
# 2     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 3     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 4     2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# ...                   ...                                      ...
# 1365  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1366  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1367  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1368  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
# 1369  2014-12-16 12:00:00  1850-01-16 12:00:00-2014-12-16 12:00:00
#
#                                                    path version
# 0     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 1     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 2     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 3     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# 4     /data/cristi/a/cristi/esm_data/cmip6_lens/ACCE...      v0
# ...                                                 ...     ...
# 1365  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1366  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1367  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1368  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
# 1369  /data/cristi/a/cristi/esm_data/cmip6_lens/NorC...      v0
#
# [1370 rows x 36 columns]

# %%
new_lats=np.arange(-87,88,2)
new_lons=np.arange(1,359,2)
new_time_index=pd.date_range(start='1850-01-16',freq='M', periods=1980)

tas_list = []

for model in cat['source_id'].drop_duplicates():
    ds_version = []
    print(model)
    for version in cat.loc[(cat['variable_id']=='tas') & (cat['source_id']==model)]['member_id'].drop_duplicates():
        path = cat.loc[(cat['variable_id']=='tas') & 
                       (cat['source_id']==model) &
                       (cat['member_id']==version)]['path'].to_list()
        ds_v = xr.open_mfdataset(path,combine='by_coords',use_cftime=True)
        ds_version.append(ds_v)
    ds = xr.concat(ds_version, dim='version',coords='minimal', compat='override')
    ds_reinterp = ds.tas.interp(lat=new_lats, lon=new_lons)
    ds_time = ds_reinterp.assign_coords(time=new_time_index)
    ds_time['name'] = model
    tas_list.append(ds_time)
# Out:
# ACCESS-CM2
# ACCESS-ESM1-5
# CNRM-CM6-1
# CNRM-ESM2-1
# CanESM5-1
# CanESM5
# E3SM-2-0
# GISS-E2-1-G
# GISS-E2-1-H
# INM-CM5-0
# IPSL-CM6A-LR
# MIROC-ES2L
# MIROC6
# MPI-ESM1-2-HR
# MPI-ESM1-2-LR
# MRI-ESM2-0
# NorCPM1

# %%
tas_cmip6 = xr.concat(tas_list, dim='name',coords='minimal', compat='override')
tas_cmip6.load()
# Out:
# <xarray.DataArray 'tas' (name: 17, version: 10, time: 1980, lat: 88, lon: 179)>
# array([[[[[252.79540934, 252.75368164, 252.72236328, ...,
#            253.21497314, 253.12849528, 252.99472168],
#           [254.5892863 , 254.51368408, 254.39644368, ...,
#            255.25633952, 255.06862386, 254.89748535],
#           [255.90585856, 255.79027344, 255.48719889, ...,
#            256.51295085, 256.30062663, 256.12380127],
#           ...,
#           [247.66450114, 248.04250977, 248.51812744, ...,
#            244.50309814, 245.7193929 , 246.63771484],
#           [245.59360352, 245.75632324, 245.94246419, ...,
#            243.97244466, 244.47064209, 245.03323975],
#           [243.70657064, 243.87456055, 244.10697428, ...,
#            242.8421818 , 243.16912842, 243.29743652]],
#
#          [[238.15461182, 238.0574707 , 237.88540039, ...,
#            239.01125895, 238.77795817, 238.56754639],
#           [241.06282959, 240.63883057, 240.26556396, ...,
#            242.89626872, 242.36745199, 241.92556152],
#           [243.46980957, 242.90199707, 242.37004395, ...,
#            245.8941862 , 245.27049967, 244.63783936],
# ...
#           [245.25348223, 245.89144897, 246.43690321, ...,
#            243.23801651, 243.68593725, 244.16082433],
#           [242.82185618, 243.08981561, 243.36123318, ...,
#            241.77358102, 242.01192602, 242.30099258],
#           [241.36285756, 241.47495448, 241.57450485, ...,
#            240.89217834, 241.00155131, 241.1164093 ]],
#
#          [[241.41072998, 241.40356801, 241.1825587 , ...,
#            242.08684743, 241.76170603, 241.67059682],
#           [244.25636605, 243.62431725, 243.42226749, ...,
#            246.08054428, 245.4638888 , 244.91268743],
#           [246.52325151, 245.73579152, 245.13322534, ...,
#            249.11330744, 248.77541478, 248.05833274],
#           ...,
#           [257.06950311, 257.44892883, 257.69030423, ...,
#            253.04921188, 254.5270551 , 255.64595295],
#           [254.00780521, 254.38849606, 254.67984772, ...,
#            251.40942824, 252.13757833, 252.90925734],
#           [250.98898366, 251.23901469, 251.44535828, ...,
#            249.76360423, 250.0769221 , 250.38291473]]]]])
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-31 1850-02-28 ... 2014-12-31
#     height   float64 2.0
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * name     (name) <U13 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'MRI-ESM2-0' 'NorCPM1'
# Dimensions without coordinates: version
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     comment:        near-surface (usually, 2 meter) air temperature
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2022-08-19T06:36:14Z altered by CMOR: Treated scalar dime...

# %%
tas_cmip6.to_netcdf('/data/keeling/a/mailes2/a/lens_processed/CMIP6_TAS_17mod_10mem.nc')

# %% [markdown]
# ## CESM2

# %%
cat_cesm = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cesm2_lens_catalog.csv')
cat_cesm
# Out:
#     component  stream                                   case  member_id  \
# 0         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001          1
# 1         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001          1
# 2         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001          1
# 3         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001          1
# 4         atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1001.001          1
# ..        ...     ...                                    ...        ...
# 845       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010         10
# 846       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010         10
# 847       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010         10
# 848       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010         10
# 849       atm  cam.h0  b.e21.BHISTcmip6.f09_g17.LE2-1301.010         10
#
#     variable start_time end_time     time_range                     long_name  \
# 0     TREFHT    1850-01  1859-12  185001-185912  Reference height temperature
# 1     TREFHT    1860-01  1869-12  186001-186912  Reference height temperature
# 2     TREFHT    1870-01  1879-12  187001-187912  Reference height temperature
# 3     TREFHT    1880-01  1889-12  188001-188912  Reference height temperature
# 4     TREFHT    1890-01  1899-12  189001-189912  Reference height temperature
# ..       ...        ...      ...            ...                           ...
# 845   TREFHT    1970-01  1979-12  197001-197912  Reference height temperature
# 846   TREFHT    1980-01  1989-12  198001-198912  Reference height temperature
# 847   TREFHT    1990-01  1999-12  199001-199912  Reference height temperature
# 848   TREFHT    2000-01  2009-12  200001-200912  Reference height temperature
# 849   TREFHT    2010-01  2014-12  201001-201412  Reference height temperature
#
#     units  vertical_levels frequency  \
# 0       K              1.0   month_1
# 1       K              1.0   month_1
# 2       K              1.0   month_1
# 3       K              1.0   month_1
# 4       K              1.0   month_1
# ..    ...              ...       ...
# 845     K              1.0   month_1
# 846     K              1.0   month_1
# 847     K              1.0   month_1
# 848     K              1.0   month_1
# 849     K              1.0   month_1
#
#                                                   path
# 0    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 1    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 2    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 3    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 4    /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# ..                                                 ...
# 845  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 846  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 847  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 848  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
# 849  /data/cristi/a/cristi/esm_data/cesm2_lens/b.e2...
#
# [850 rows x 13 columns]

# %%
path_cesm2 = cat_cesm['path'].to_list()
path_cesm2
# Out:
# ['/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1041.003.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1061.004.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1081.005.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1101.006.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1121.007.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1141.008.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1161.009.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1181.010.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.001.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.002.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.003.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.004.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.005.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.006.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.007.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.008.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.009.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1231.010.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h0.TREFHT.193001-193912.nc',
# ...
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.002.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.002.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.002.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.003.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.004.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.005.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.006.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.007.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.008.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.009.cam.h0.TREFHT.201001-201412.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.185001-185912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.186001-186912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.187001-187912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.188001-188912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.189001-189912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.190001-190912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.191001-191912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.192001-192912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.193001-193912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.194001-194912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.195001-195912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.196001-196912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.197001-197912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.198001-198912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.199001-199912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.200001-200912.nc',
#  '/data/cristi/a/cristi/esm_data/cesm2_lens/b.e21.BHISTcmip6.f09_g17.LE2-1301.010.cam.h0.TREFHT.201001-201412.nc']

# %%
tas_cesm2 = xr.open_mfdataset(path_cesm2, combine='nested', combine="by_coords", use_cftime=True)
tas_cesm2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 tas_cesm2 = xr.open_mfdataset(path_cesm2, coords='nested', combine="by_coords", use_cftime=True)
#       2 tas_cesm2
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/backends/api.py:1024, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1011     combined = _nested_combine(
#    1012         datasets,
#    1013         concat_dims=concat_dim,
#    (...)
#    1019         combine_attrs=combine_attrs,
#    1020     )
#    1021 elif combine == "by_coords":
#    1022     # Redo ordering from coordinates, ignoring how they were ordered
#    1023     # previously
# -> 1024     combined = combine_by_coords(
#    1025         datasets,
#    1026         compat=compat,
#    1027         data_vars=data_vars,
#    1028         coords=coords,
#    1029         join=join,
#    1030         combine_attrs=combine_attrs,
#    1031     )
#    1032 else:
#    1033     raise ValueError(
#    1034         "{} is an invalid option for the keyword argument"
#    1035         " ``combine``".format(combine)
#    1036     )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/combine.py:982, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs, datasets)
#     980     concatenated_grouped_by_data_vars = []
#     981     for vars, datasets_with_same_vars in grouped_by_vars:
# --> 982         concatenated = _combine_single_variable_hypercube(
#     983             list(datasets_with_same_vars),
#     984             fill_value=fill_value,
#     985             data_vars=data_vars,
#     986             coords=coords,
#     987             compat=compat,
#     988             join=join,
#     989             combine_attrs=combine_attrs,
#     990         )
#     991         concatenated_grouped_by_data_vars.append(concatenated)
#     993 return merge(
#     994     concatenated_grouped_by_data_vars,
#     995     compat=compat,
#    (...)
#     998     combine_attrs=combine_attrs,
#     999 )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/combine.py:640, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     637     _check_dimension_depth_tile_ids(combined_ids)
#     639 # Concatenate along all of concat_dims one by one to create single ds
# --> 640 concatenated = _combine_nd(
#     641     combined_ids,
#     642     concat_dims=concat_dims,
#     643     data_vars=data_vars,
#     644     coords=coords,
#     645     compat=compat,
#     646     fill_value=fill_value,
#     647     join=join,
#     648     combine_attrs=combine_attrs,
#     649 )
#     651 # Check the overall coordinates are monotonically increasing
#     652 for dim in concat_dims:
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/combine.py:239, in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat, fill_value, join, combine_attrs)
#     235 # Each iteration of this loop reduces the length of the tile_ids tuples
#     236 # by one. It always combines along the first dimension, removing the first
#     237 # element of the tuple
#     238 for concat_dim in concat_dims:
# --> 239     combined_ids = _combine_all_along_first_dim(
#     240         combined_ids,
#     241         dim=concat_dim,
#     242         data_vars=data_vars,
#     243         coords=coords,
#     244         compat=compat,
#     245         fill_value=fill_value,
#     246         join=join,
#     247         combine_attrs=combine_attrs,
#     248     )
#     249 (combined_ds,) = combined_ids.values()
#     250 return combined_ds
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/combine.py:275, in _combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat, fill_value, join, combine_attrs)
#     273     combined_ids = dict(sorted(group))
#     274     datasets = combined_ids.values()
# --> 275     new_combined_ids[new_id] = _combine_1d(
#     276         datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#     277     )
#     278 return new_combined_ids
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/combine.py:298, in _combine_1d(datasets, concat_dim, compat, data_vars, coords, fill_value, join, combine_attrs)
#     296 if concat_dim is not None:
#     297     try:
# --> 298         combined = concat(
#     299             datasets,
#     300             dim=concat_dim,
#     301             data_vars=data_vars,
#     302             coords=coords,
#     303             compat=compat,
#     304             fill_value=fill_value,
#     305             join=join,
#     306             combine_attrs=combine_attrs,
#     307         )
#     308     except ValueError as err:
#     309         if "encountered unexpected variable" in str(err):
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:243, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     231     return _dataarray_concat(
#     232         objs,
#     233         dim=dim,
#    (...)
#     240         combine_attrs=combine_attrs,
#     241     )
#     242 elif isinstance(first_obj, Dataset):
# --> 243     return _dataset_concat(
#     244         objs,
#     245         dim=dim,
#     246         data_vars=data_vars,
#     247         coords=coords,
#     248         compat=compat,
#     249         positions=positions,
#     250         fill_value=fill_value,
#     251         join=join,
#     252         combine_attrs=combine_attrs,
#     253     )
#     254 else:
#     255     raise TypeError(
#     256         "can only concatenate xarray Dataset and DataArray "
#     257         f"objects, got {type(first_obj)}"
#     258     )
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:488, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     485     datasets = [cast(T_Dataset, ds.expand_dims(dim)) for ds in datasets]
#     487 # determine which variables to concatenate
# --> 488 concat_over, equals, concat_dim_lengths = _calc_concat_over(
#     489     datasets, dim, dim_names, data_vars, coords, compat
#     490 )
#     492 # determine which variables to merge, and then merge them according to compat
#     493 variables_to_merge = (coord_names | data_names) - concat_over - unlabeled_dims
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:398, in _calc_concat_over(datasets, dim, dim_names, data_vars, coords, compat)
#     395         concat_over.update(opt)
#     397 process_subset_opt(data_vars, "data_vars")
# --> 398 process_subset_opt(coords, "coords")
#     399 return concat_over, equals, concat_dim_lengths
#
# File ~/miniconda3/envs/paleoproj/lib/python3.10/site-packages/xarray/core/concat.py:381, in _calc_concat_over.<locals>.process_subset_opt(opt, subset)
#     379         pass
#     380     else:
# --> 381         raise ValueError(f"unexpected value for {subset}: {opt}")
#     382 else:
#     383     invalid_vars = [k for k in opt if k not in getattr(datasets[0], subset)]
#
# ValueError: unexpected value for coords: nested

# %%
tas_cesm2.TREFHT

# %%
cat_cesm['case']
# Out:
# 0      b.e21.BHISTcmip6.f09_g17.LE2-1001.001
# 1      b.e21.BHISTcmip6.f09_g17.LE2-1001.001
# 2      b.e21.BHISTcmip6.f09_g17.LE2-1001.001
# 3      b.e21.BHISTcmip6.f09_g17.LE2-1001.001
# 4      b.e21.BHISTcmip6.f09_g17.LE2-1001.001
#                        ...
# 845    b.e21.BHISTcmip6.f09_g17.LE2-1301.010
# 846    b.e21.BHISTcmip6.f09_g17.LE2-1301.010
# 847    b.e21.BHISTcmip6.f09_g17.LE2-1301.010
# 848    b.e21.BHISTcmip6.f09_g17.LE2-1301.010
# 849    b.e21.BHISTcmip6.f09_g17.LE2-1301.010
# Name: case, Length: 850, dtype: object
