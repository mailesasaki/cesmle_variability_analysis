# %%
# Load modules

import xarray as xr
import pandas as pd
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import zarr
import gcsfs

# %% [markdown]
# # Load data

# %%
vert_ds = xr.open_dataarray('/data/keeling/a/mailes2/cesmle_variability_analysis/processed_data/vert_ds.nc')

dataarray_SST_hist = xr.open_dataarray('/data/keeling/a/mailes2/a/processed_var_data/CMIP_sst_historical_interp_2x2_15memens.nc')
dataarray_SST_hist.load()

dataarray_TOA_hist = xr.open_dataarray('/data/keeling/a/mailes2/a/processed_var_data/CMIP_toa_historical_2x2_15memens.nc')
dataarray_TOA_hist.load()

dataarray_Qs_hist = xr.open_dataarray('/data/keeling/a/mailes2/a/processed_var_data/CMIP_surface_hist_interp_15memens.nc')
dataarray_Qs_hist.load()
# Out:
# <xarray.DataArray (name: 15, time: 1500, lat: 88, lon: 179)>
# array([[[[ 4.90165056e+00,  5.02030481e+00,  5.14833517e+00, ...,
#            4.42925605e+00,  4.56485558e+00,  4.66646627e+00],
#          [ 4.59733384e+00,  4.82168076e+00,  4.98723783e+00, ...,
#            3.81284670e+00,  3.96564983e+00,  4.19904078e+00],
#          [ 4.02822119e+00,  4.18452456e+00,  4.37871187e+00, ...,
#            3.16195200e+00,  3.32776068e+00,  3.54453707e+00],
#          ...,
#          [-3.46124473e+01, -3.68575683e+01, -3.48434307e+01, ...,
#           -3.44554857e+01, -3.57958553e+01, -3.51358641e+01],
#          [-3.32735436e+01, -3.38893754e+01, -3.38385741e+01, ...,
#           -3.26756667e+01, -3.27437460e+01, -3.27906597e+01],
#          [-3.46177860e+01, -3.51192427e+01, -3.58445793e+01, ...,
#           -3.36690564e+01, -3.51623532e+01, -3.55597275e+01]],
#
#         [[-2.86197465e+00, -2.93874279e+00, -3.03927916e+00, ...,
#           -2.56575976e+00, -2.67832265e+00, -2.74031600e+00],
#          [-2.12785747e+00, -2.32005957e+00, -2.40554916e+00, ...,
#           -1.76238901e+00, -1.80849465e+00, -1.92474648e+00],
#          [-1.41721594e+00, -1.48068312e+00, -1.55627523e+00, ...,
#           -9.75113796e-01, -1.02866159e+00, -1.15787975e+00],
# ...
#          [-2.78088935e+01, -2.78776526e+01, -2.93542580e+01, ...,
#           -1.90225108e+01, -1.93425562e+01, -2.20628261e+01],
#          [-2.44885393e+01, -2.53342339e+01, -2.67468318e+01, ...,
#           -1.73685251e+01, -2.00562108e+01, -2.04017211e+01],
#          [-2.17705019e+01, -2.34594400e+01, -2.61322040e+01, ...,
#           -2.20741132e+01, -2.23441102e+01, -2.22555440e+01]],
#
#         [[ 2.00020313e+01,  2.02547712e+01,  2.04408099e+01, ...,
#            1.97594779e+01,  1.98033927e+01,  1.99940870e+01],
#          [ 1.87190357e+01,  1.87650739e+01,  1.88504934e+01, ...,
#            1.84766899e+01,  1.86177975e+01,  1.85550708e+01],
#          [ 1.79714223e+01,  1.81370286e+01,  1.83174774e+01, ...,
#            1.72408851e+01,  1.75626934e+01,  1.76884266e+01],
#          ...,
#          [-3.28068227e+01, -3.18609009e+01, -3.11594645e+01, ...,
#           -2.05865988e+01, -2.25901160e+01, -2.73886632e+01],
#          [-2.14137497e+01, -2.32414394e+01, -2.30369152e+01, ...,
#           -1.75088925e+01, -1.97793967e+01, -2.07191078e+01],
#          [-2.20522095e+01, -2.36049736e+01, -2.36618611e+01, ...,
#           -2.03961387e+01, -2.12793080e+01, -2.13185888e+01]]]])
# Coordinates:
#   * time     (time) datetime64[ns] 1851-01-31 1851-02-28 ... 1975-12-31
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * name     (name) object 'BCC-CSM2-MR' 'BCC-ESM1' ... 'NESM3'

# %%
def monthlylag_fit(sst_dataset, rad_dataset):
    """
    Monthly lagged regression
    
    """
    rad_dataset_lag = rad_dataset.shift(time=-1).isel(time=slice(0,1499))
    sst_dataset_lag = sst_dataset.isel(time=slice(0,1499))
    
    SST_radfit = xr.DataArray(np.zeros((15,88,179)), dims=['name','lat','lon'])
    model_index = 0
    for model in rad_dataset_lag.coords['name'].values:
        lat_index = 0
        for lat in rad_dataset_lag.coords['lat'].values:
            lon_index = 0
            for lon in rad_dataset_lag.coords['lon'].values:
                SST_slice = sst_dataset_lag.sel(lat=lat).sel(lon=lon).sel(name=model)
                rad_slice = rad_dataset_lag.sel(lat=lat).sel(lon=lon).sel(name=model)
                idx = np.isfinite(SST_slice) & np.isfinite(rad_slice)
                if not SST_slice[idx].size or not rad_slice[idx].size:
                    break
                SST_radfit[model_index, lat_index, lon_index] = np.polyfit(SST_slice[idx], rad_slice[idx], deg=1)[0]     
                lon_index += 1
            lat_index += 1
        model_index += 1
        print(model)

    SST_radfit.coords['lon'] = rad_dataset['lon'].values
    SST_radfit.coords['lat'] = rad_dataset['lat'].values
    SST_radfit.coords['name'] = rad_dataset['name'].values
    SST_radfit
    return SST_radfit

# %% [markdown]
# # SST and TOA

# %%
sst_toa_fit = monthlylag_fit(dataarray_SST_hist, dataarray_TOA_hist)
# Out:
# BCC-CSM2-MR
# BCC-ESM1
# CESM2
# CNRM-CM6-1
# CNRM-ESM2-1
# CanESM5-CanOE
# CanESM5
# EC-Earth3
# GISS-E2-1-G
# HadGEM3-GC31-LL
# INM-CM4-8
# INM-CM5-0
# IPSL-CM6A-LR
# MPI-ESM-1-2-HAM
# NESM3

# %%
sst_toa_fit
# Out:
# <xarray.DataArray (name: 15, lat: 88, lon: 179)>
# array([[[1.94084716, 1.92923984, 1.91781248, ..., 1.99864418,
#          1.98320184, 1.96792332],
#         [1.85883133, 1.83893259, 1.82117267, ..., 1.97263987,
#          1.93924524, 1.9094007 ],
#         [1.83317576, 1.8019257 , 1.77560188, ..., 2.01172859,
#          1.9598386 , 1.91213912],
#         ...,
#         [1.82925036, 1.82120879, 1.80952617, ..., 1.85440291,
#          1.84980732, 1.83736737],
#         [1.77178351, 1.77077317, 1.77464244, ..., 1.77129407,
#          1.76927165, 1.7677358 ],
#         [1.73892145, 1.7421057 , 1.74266684, ..., 1.72520505,
#          1.73128853, 1.73231429]],
#
#        [[1.75251252, 1.74570302, 1.73973807, ..., 1.78032003,
#          1.77295767, 1.76566433],
#         [1.66334682, 1.65126692, 1.64082122, ..., 1.71515017,
#          1.7014777 , 1.68784218],
#         [1.60365072, 1.59113967, 1.58014278, ..., 1.66147542,
#          1.64575271, 1.63067685],
# ...
#         [1.5231218 , 1.52480412, 1.52980766, ..., 1.56943527,
#          1.54871155, 1.53466969],
#         [1.42962193, 1.44318045, 1.45748506, ..., 1.38920907,
#          1.39739571, 1.40701096],
#         [1.38929625, 1.39443186, 1.39996191, ..., 1.37000429,
#          1.37492771, 1.3796516 ]],
#
#        [[1.17635813, 1.17533272, 1.17585271, ..., 1.19700421,
#          1.19229784, 1.18602021],
#         [1.03697993, 1.03338322, 1.03581035, ..., 1.08335871,
#          1.06642253, 1.05432052],
#         [1.07688777, 1.07478587, 1.07855316, ..., 1.15559436,
#          1.12622972, 1.10226244],
#         ...,
#         [0.94237314, 0.94558092, 0.95580623, ..., 0.97361895,
#          0.95607754, 0.94694945],
#         [0.89223318, 0.89816944, 0.90483361, ..., 0.87850153,
#          0.87856439, 0.87908821],
#         [0.91270062, 0.91453942, 0.91727777, ..., 0.90010561,
#          0.90209095, 0.90583592]]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87
#   * name     (name) object 'BCC-CSM2-MR' 'BCC-ESM1' ... 'NESM3'

# %%
sst_toa_fit_mean = sst_toa_fit.mean('name')

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_toa_fit_mean.plot(ax=ax, transform=ccrs.PlateCarree(), vmin=-30, vmax=30, cmap='RdBu_r')
ax.coastlines(color='black', linewidth=1)
vert_ds.plot.contour(ax=ax, transform=ccrs.PlateCarree(), colors='#808080', levels=[-0.005,0.005])
plt.title('Monthly Lagged Regression of Historical SST and TOA Radiation (N=15)')
# Out:
# Text(0.5, 1.0, 'Monthly Lagged Regression of Historical SST and TOA Radiation (N=15)')

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_toa_fit_mean.plot(ax=ax, transform=ccrs.PlateCarree(), vmin=-30, vmax=30, cmap='RdBu_r')
ax.coastlines(color='black', linewidth=1)
plt.title('Monthly Lagged Regression of Historical SST and TOA Radiation (N=15)')
# Out:
# Text(0.5, 1.0, 'Monthly Lagged Regression of Historical SST and TOA Radiation (N=15)')

# %% [markdown]
# # SST and Surface

# %%
sst_surface_fit = monthlylag_fit(dataarray_SST_hist, dataarray_Qs_hist)
# Out:
# BCC-CSM2-MR
# BCC-ESM1
# CESM2
# CNRM-CM6-1
# CNRM-ESM2-1
# CanESM5-CanOE
# CanESM5
# EC-Earth3
# GISS-E2-1-G
# HadGEM3-GC31-LL
# INM-CM4-8
# INM-CM5-0
# IPSL-CM6A-LR
# MPI-ESM-1-2-HAM
# NESM3

# %%
sst_surface_fit_mean = sst_surface_fit.mean('name')

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_surface_fit_mean.plot(ax=ax, transform=ccrs.PlateCarree(), vmin=-30, vmax=30, cmap='RdBu_r')
ax.coastlines(color='black', linewidth=1)
vert_ds.plot.contour(ax=ax, transform=ccrs.PlateCarree(), colors='#808080', levels=[-0.005,0.005])
plt.title('Monthly Lagged Regression of Historical SST and Surface Radiation (N=15)')
# Out:
# Text(0.5, 1.0, 'Monthly Lagged Regression of Historical SST and Surface Radiation (N=15)')

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_surface_fit_mean.plot(ax=ax, transform=ccrs.PlateCarree(), vmin=-30, vmax=30, cmap='RdBu_r')
ax.coastlines(color='black', linewidth=1)
plt.title('Monthly Lagged Regression of Historical SST and Surface Radiation (N=15)')
# Out:
# Text(0.5, 1.0, 'Monthly Lagged Regression of Historical SST and Surface Radiation (N=15)')

# %% [markdown]
# # Testing

# %%
rad_dataset_lag_test = dataarray_TOA_hist.shift(time=-1).isel(time=slice(0,1499))
rad_dataset_lag_test
# Out:
# <xarray.DataArray (name: 15, time: 1499, lat: 88, lon: 179)>
# array([[[[ -77.64925593,  -77.38441756,  -77.12490828, ...,
#            -78.73775416,  -78.47043612,  -78.18227489],
#          [ -79.8017584 ,  -79.43750621,  -79.0456798 , ...,
#            -81.49615103,  -81.01476512,  -80.59659103],
#          [ -83.09610685,  -82.41270824,  -81.7879474 , ...,
#            -86.35207228,  -85.49494116,  -84.66419917],
#          ...,
#          [-163.40315193, -163.04561387, -162.65782452, ...,
#           -162.37993672, -162.88885326, -163.19577593],
#          [-159.21811911, -159.44019876, -159.664098  , ...,
#           -158.18926657, -158.47407436, -158.70660662],
#          [-156.63491927, -156.78956042, -156.79244654, ...,
#           -156.31301746, -156.44213658, -156.4079114 ]],
#
#         [[-131.99084262, -131.7351342 , -131.47227176, ...,
#           -133.05821112, -132.83970176, -132.56577548],
#          [-132.24157454, -131.8963938 , -131.4500925 , ...,
#           -134.28745284, -133.71073553, -133.20891426],
#          [-133.34630552, -132.74288561, -132.18363496, ...,
#           -136.07369518, -135.31363564, -134.66231979],
# ...
#          [-190.00311939, -190.80699795, -191.51516202, ...,
#           -188.44678882, -188.92862686, -188.95906369],
#          [-187.95129824, -187.72854749, -188.11896437, ...,
#           -186.10026971, -186.82349829, -186.83598057],
#          [-186.86608359, -187.0886825 , -187.43187681, ...,
#           -184.20199573, -184.72399066, -185.55639261]],
#
#         [[ -24.43813969,  -24.84779971,  -24.92879227, ...,
#            -25.30986894,  -24.82006257,  -24.86068453],
#          [ -26.79795573,  -26.78310288,  -26.76178377, ...,
#            -27.7577471 ,  -27.40283659,  -27.06011935],
#          [ -29.38564924,  -29.06398698,  -28.67490385, ...,
#            -31.41178425,  -31.01536289,  -30.53263186],
#          ...,
#          [-165.12963183, -165.23172683, -165.41421174, ...,
#           -164.31337828, -164.29590919, -164.47407868],
#          [-165.02561653, -165.35161079, -165.51151213, ...,
#           -164.49130426, -164.62586611, -164.51511954],
#          [-165.1235772 , -165.26552377, -165.37453287, ...,
#           -165.07025222, -164.99571096, -165.02692454]]]])
# Coordinates:
#   * time     (time) datetime64[ns] 1851-01-31 1851-02-28 ... 1975-11-30
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * name     (name) object 'BCC-CSM2-MR' 'BCC-ESM1' ... 'NESM3'

# %%
print(np.polyfit(dataarray_SST_hist.isel(lat=1).isel(lon=1).isel(name=1), 
                                                           dataarray_TOA_hist.isel(lat=1).isel(lon=1).isel(name=1), deg=1))

# Zeroth - Slope
# First - Intercept
# Out:
# [   2.22480668 -590.82148965]

# %%
def monthlylag_fit_intercept(sst_dataset, rad_dataset):
    """
    Monthly lagged regression
    
    """
    rad_dataset_lag = rad_dataset.shift(time=-1).isel(time=slice(0,1499))
    sst_dataset_lag = sst_dataset.isel(time=slice(0,1499))
    
    SST_radfit = xr.DataArray(np.zeros((15,88,179)), dims=['name','lat','lon'])
    model_index = 0
    for model in rad_dataset_lag.coords['name'].values:
        lat_index = 0
        for lat in rad_dataset_lag.coords['lat'].values:
            lon_index = 0
            for lon in rad_dataset_lag.coords['lon'].values:
                SST_slice = sst_dataset_lag.sel(lat=lat).sel(lon=lon).sel(name=model)
                rad_slice = rad_dataset_lag.sel(lat=lat).sel(lon=lon).sel(name=model)
                idx = np.isfinite(SST_slice) & np.isfinite(rad_slice)
                if not SST_slice[idx].size or not rad_slice[idx].size:
                    break
                SST_radfit[model_index, lat_index, lon_index] = np.polyfit(SST_slice[idx], rad_slice[idx], deg=1)[1]     
                lon_index += 1
            lat_index += 1
        model_index += 1
        print(model)

    SST_radfit.coords['lon'] = rad_dataset['lon'].values
    SST_radfit.coords['lat'] = rad_dataset['lat'].values
    SST_radfit.coords['name'] = rad_dataset['name'].values
    SST_radfit
    return SST_radfit

# %%
sst_toa_fit_intercept = monthlylag_fit_intercept(dataarray_SST_hist, dataarray_TOA_hist)
# Out:
# BCC-CSM2-MR
# BCC-ESM1
# CESM2
# CNRM-CM6-1
# CNRM-ESM2-1
# CanESM5-CanOE
# CanESM5
# EC-Earth3
# GISS-E2-1-G
# HadGEM3-GC31-LL
# INM-CM4-8
# INM-CM5-0
# IPSL-CM6A-LR
# MPI-ESM-1-2-HAM
# NESM3

# %%
sst_toa_fit_intercept
# Out:
# <xarray.DataArray (name: 15, lat: 88, lon: 179)>
# array([[[-535.1489351 , -531.79353838, -528.53936586, ...,
#          -551.47618985, -547.11879815, -542.82919416],
#         [-519.233077  , -513.51246416, -508.38204881, ...,
#          -551.11908662, -541.8414419 , -533.4940639 ],
#         [-518.83550112, -509.75069398, -502.00819593, ...,
#          -569.58673718, -554.92229735, -541.41925721],
#         ...,
#         [-585.70681451, -584.02657499, -581.45998999, ...,
#          -590.15867306, -589.5597343 , -586.87455852],
#         [-571.02603257, -570.96496331, -572.16480962, ...,
#          -570.13353196, -569.79316009, -569.59712301],
#         [-562.84573191, -563.73113038, -563.95944363, ...,
#          -559.11094164, -560.72796395, -561.04299673]],
#
#        [[-492.02427693, -489.56453557, -487.30120359, ...,
#          -502.0139004 , -499.42760211, -496.85259242],
#         [-474.60600391, -470.24015856, -466.27229089, ...,
#          -493.02185629, -488.24092946, -483.46983118],
#         [-463.40112056, -458.40634096, -453.82695376, ...,
#          -485.73194314, -479.77448511, -474.0147778 ],
# ...
#         [-515.49495888, -516.45926036, -518.20937683, ...,
#          -524.24530623, -519.88017087, -517.1036007 ],
#         [-488.83942452, -492.53731278, -496.41445842, ...,
#          -477.41963199, -479.81783036, -482.55574716],
#         [-476.91414504, -478.27589567, -479.73594051, ...,
#          -471.74217598, -473.0636055 , -474.33236617]],
#
#        [[-356.78393739, -356.31701619, -356.22691491, ...,
#          -362.79707505, -361.30712413, -359.53029126],
#         [-328.52032467, -327.33214311, -327.57268291, ...,
#          -341.46812759, -336.86674909, -333.45749934],
#         [-344.48343475, -343.04667632, -343.04780183, ...,
#          -367.32149005, -359.20427717, -352.44810629],
#         ...,
#         [-362.21215568, -363.16675935, -365.93432442, ...,
#          -368.963528  , -364.8799129 , -362.88965545],
#         [-348.5853632 , -350.13341078, -351.8804977 , ...,
#          -344.70661458, -344.85470629, -345.06456282],
#         [-353.5005308 , -354.01727385, -354.76765832, ...,
#          -350.12846222, -350.70412434, -351.71108265]]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87
#   * name     (name) object 'BCC-CSM2-MR' 'BCC-ESM1' ... 'NESM3'

# %%
sst_toa_fit_intercept_mean = sst_toa_fit_intercept.mean('name')

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_toa_fit_intercept_mean.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines(color='black', linewidth=1)
vert_ds.plot.contour(ax=ax, transform=ccrs.PlateCarree(), colors='#808080', levels=[-0.005,0.005])
plt.title('Monthly Lagged Regression Intercept of Historical SST and TOA Radiation (N=15)')
# Out:
# Text(0.5, 1.0, 'Monthly Lagged Regression Intercept of Historical SST and TOA Radiation (N=15)')
