# %%
# Load all libraries

import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import matplotlib
import cartopy

# %%
SST = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TS_piControl.nc')
SST.load()

TAS = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TREFHT_piControl.nc')
TAS.load()

surface = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_Surfacefluxes.nc')
surface.load()

TOA = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TOAfluxes.nc')
TOA.load()

horiz = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_Horizfluxes.nc')
horiz.load()
# Out:
# <xarray.DataArray (time: 10812, lat: 88, lon: 179)>
# array([[[ 42.53542777,  41.927426  ,  42.58697592, ...,  43.21527401,
#           43.25190393,  41.80356174],
#         [ 42.87182134,  43.14402141,  42.71662311, ...,  46.01358524,
#           44.63607445,  45.88991679],
#         [ 46.99448397,  46.83794392,  46.28594548, ...,  49.82213598,
#           49.17078888,  46.92960561],
#         ...,
#         [136.48443915, 136.40939829, 136.491963  , ..., 137.46363015,
#          136.85699853, 136.13773218],
#         [134.6040023 , 134.52763522, 134.42945035, ..., 135.66291789,
#          135.08495096, 134.45514554],
#         [134.10991327, 133.78173311, 133.7355444 , ..., 134.64990205,
#          134.654816  , 134.60242641]],
#
#        [[ 73.43730374,  72.7522067 ,  72.9338999 , ...,  74.44936102,
#           74.22802165,  73.29133068],
#         [ 73.82323661,  73.48583438,  72.55434423, ...,  77.24610901,
#           76.16156273,  76.66161903],
# ...

# %%
def yearlylag_fit(sst_dataset, rad_dataset, datatype='none'):
    """
    Yearly lagged regression
    
    """

    rad_dataset_yearly = rad_dataset.shift(time=-12).isel(time=slice(0,1488)) # Lagged by a year
    rad_dataset_yearly = rad_dataset_yearly.rolling(time=12, center=True).mean('time') # Mean over the year
    rad_dataset_yearly = rad_dataset_yearly.isel(time=slice(12,1476))
    sst_dataset_yearly = sst_dataset.rolling(time=12, center=True).mean('time') # Mean over the year
    sst_dataset_yearly = sst_dataset_yearly.isel(time=slice(12,1476))
    
    SST_radfit = xr.DataArray(np.zeros((88,179)), dims=['lat','lon'])
    lat_index = 0
    for lat in rad_dataset_yearly.coords['lat'].values:
        lon_index = 0
        for lon in rad_dataset_yearly.coords['lon'].values:
            SST_slice = sst_dataset_yearly.sel(lat=lat).sel(lon=lon)
            rad_slice = rad_dataset_yearly.sel(lat=lat).sel(lon=lon)
            SST_radfit[lat_index, lon_index] = np.polyfit(SST_slice, rad_slice, deg=1)[0]     
            lon_index += 1
        lat_index += 1

    SST_radfit.coords['lon'] = rad_dataset_yearly['lon'].values
    SST_radfit.coords['lat'] = rad_dataset_yearly['lat'].values
    SST_radfit
    return SST_radfit

# %% [markdown]
# # Surface

# %%
sst_surface_fit = yearlylag_fit(SST, surface)
sst_surface_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-0.1175228 , -0.11314357, -0.11273294, ..., -0.12417133,
#         -0.11422911, -0.12781837],
#        [-0.11610841, -0.1173988 , -0.11837969, ..., -0.12943605,
#         -0.12357354, -0.11909009],
#        [-0.11560484, -0.11949596, -0.1118758 , ..., -0.12187737,
#         -0.12088813, -0.12089926],
#        ...,
#        [ 0.02410156,  0.03142703,  0.02987546, ..., -0.06724331,
#         -0.0348614 , -0.00610024],
#        [-0.1011266 , -0.08904651, -0.07362261, ..., -0.16283196,
#         -0.14303449, -0.13453302],
#        [-0.10516827, -0.10056102, -0.0971683 , ..., -0.15541417,
#         -0.1369412 , -0.12486568]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_surface_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TS and Surface Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TS and Surface Radiation')

# %%
tas_surface_fit = yearlylag_fit(TAS, surface)
tas_surface_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-0.11765782, -0.11253899, -0.11378191, ..., -0.12337517,
#         -0.11475789, -0.12750383],
#        [-0.11861905, -0.12023334, -0.12148954, ..., -0.13099576,
#         -0.12418641, -0.1219999 ],
#        [-0.11501468, -0.11782013, -0.11132652, ..., -0.11960085,
#         -0.11933789, -0.117907  ],
#        ...,
#        [ 0.02879969,  0.03781752,  0.03731499, ..., -0.06752851,
#         -0.03359635, -0.00416931],
#        [-0.10144822, -0.08865779, -0.07258084, ..., -0.16658527,
#         -0.14604865, -0.13644077],
#        [-0.1088149 , -0.10416518, -0.10053886, ..., -0.16091674,
#         -0.14220256, -0.12945527]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_surface_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TAS and Surface Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TAS and Surface Radiation')

# %% [markdown]
# # TOA

# %%
sst_toa_fit = yearlylag_fit(SST, TOA)
sst_toa_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-0.0991632 , -0.09320388, -0.14221653, ..., -0.08046686,
#         -0.01216223, -0.13104671],
#        [-0.1189804 , -0.14801492, -0.16806914, ..., -0.10363756,
#         -0.09005489, -0.09762711],
#        [-0.13366314, -0.17928766, -0.10371929, ..., -0.10585047,
#         -0.09168298, -0.12362972],
#        ...,
#        [-0.04863897, -0.03403899, -0.02333922, ..., -0.14225398,
#         -0.1227448 , -0.09657625],
#        [-0.10056656, -0.08547444, -0.07293257, ..., -0.14129093,
#         -0.12909347, -0.12058019],
#        [-0.05523541, -0.04691709, -0.03793398, ..., -0.09460143,
#         -0.08434439, -0.0723171 ]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_toa_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TS and TOA Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TS and TOA Radiation')

# %%
tas_toa_fit = yearlylag_fit(TAS, TOA)
tas_toa_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-0.13727002, -0.12715605, -0.16350678, ..., -0.10504555,
#         -0.03080837, -0.16796327],
#        [-0.12628633, -0.15514601, -0.1718681 , ..., -0.11229757,
#         -0.09710978, -0.09311016],
#        [-0.12495871, -0.17272281, -0.10175216, ..., -0.10170382,
#         -0.09167231, -0.11976424],
#        ...,
#        [-0.05433586, -0.03824713, -0.02623773, ..., -0.15129138,
#         -0.13177976, -0.10490723],
#        [-0.1091993 , -0.09334948, -0.08035063, ..., -0.15253466,
#         -0.13945457, -0.1302143 ],
#        [-0.07004291, -0.06179719, -0.05294774, ..., -0.10764987,
#         -0.09786153, -0.08654187]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_toa_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TAS and TOA Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TAS and TOA Radiation')

# %% [markdown]
# # Horiz

# %%
sst_horiz_fit = yearlylag_fit(SST, horiz)
sst_horiz_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-0.0183596 , -0.01993969,  0.02948358, ..., -0.04370448,
#         -0.10206688,  0.00322833],
#        [ 0.00287199,  0.03061612,  0.04968945, ..., -0.02579849,
#         -0.03351865, -0.02146298],
#        [ 0.0180583 ,  0.05979171, -0.00815652, ..., -0.0160269 ,
#         -0.02920514,  0.00273046],
#        ...,
#        [ 0.07274052,  0.06546603,  0.05321468, ...,  0.07501067,
#          0.0878834 ,  0.090476  ],
#        [-0.00056004, -0.00357207, -0.00069004, ..., -0.02154103,
#         -0.01394102, -0.01395283],
#        [-0.04993286, -0.05364392, -0.05923431, ..., -0.06081274,
#         -0.05259681, -0.05254858]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_horiz_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TS and Horiz Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TS and Horiz Radiation')

# %%
tas_horiz_fit = yearlylag_fit(TAS, horiz)
tas_horiz_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[ 0.0196122 ,  0.01461706,  0.04972487, ..., -0.01832962,
#         -0.08394952,  0.04045944],
#        [ 0.00766728,  0.03491267,  0.05037856, ..., -0.01869819,
#         -0.02707663, -0.02888974],
#        [ 0.00994403,  0.05490268, -0.00957436, ..., -0.01789703,
#         -0.02766558,  0.00185723],
#        ...,
#        [ 0.08313555,  0.07606465,  0.06355272, ...,  0.08376287,
#          0.09818341,  0.10073791],
#        [ 0.00775108,  0.00469169,  0.00776979, ..., -0.01405061,
#         -0.00659408, -0.00622646],
#        [-0.03877199, -0.04236799, -0.04759112, ..., -0.05326687,
#         -0.04434103, -0.0429134 ]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_horiz_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-5, vmax=5)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Lagged Regression of Slab Ocean TAS and Horiz Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Lagged Regression of Slab Ocean TAS and Horiz Radiation')
