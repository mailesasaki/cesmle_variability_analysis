# %%
# Load all libraries

import xarray as xr
import pathlib
from os import listdir
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
from matplotlib import gridspec
import matplotlib
import xesmf as xe
import cartopy

# %%
SST = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TS_piControl.nc')
SST.load()

TAS = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TREFHT_piControl.nc')
TAS.load()

surface = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_Surfacefluxes.nc')
surface.load()

TOA = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_TOAfluxes.nc')
TOA.load()

horiz = xr.open_dataarray('/data/keeling/a/mailes2/a/alt_compset_processed/CESM1_E_Horizfluxes.nc')
horiz.load()
# Out:
# <xarray.DataArray (time: 10812, lat: 88, lon: 179)>
# array([[[ 42.53542777,  41.927426  ,  42.58697592, ...,  43.21527401,
#           43.25190393,  41.80356174],
#         [ 42.87182134,  43.14402141,  42.71662311, ...,  46.01358524,
#           44.63607445,  45.88991679],
#         [ 46.99448397,  46.83794392,  46.28594548, ...,  49.82213598,
#           49.17078888,  46.92960561],
#         ...,
#         [136.48443915, 136.40939829, 136.491963  , ..., 137.46363015,
#          136.85699853, 136.13773218],
#         [134.6040023 , 134.52763522, 134.42945035, ..., 135.66291789,
#          135.08495096, 134.45514554],
#         [134.10991327, 133.78173311, 133.7355444 , ..., 134.64990205,
#          134.654816  , 134.60242641]],
#
#        [[ 73.43730374,  72.7522067 ,  72.9338999 , ...,  74.44936102,
#           74.22802165,  73.29133068],
#         [ 73.82323661,  73.48583438,  72.55434423, ...,  77.24610901,
#           76.16156273,  76.66161903],
# ...

# %%
def yearly_fit(sst_dataset, rad_dataset, datatype='none'):
    """
    Yearly regression
    
    """
    rad_dataset_yearly = rad_dataset.rolling(time=12, center=True).mean('time')
    rad_dataset_yearly = rad_dataset_yearly.isel(time=slice(12,1488))
    sst_dataset_yearly = sst_dataset.rolling(time=12, center=True).mean('time')
    sst_dataset_yearly = sst_dataset_yearly.isel(time=slice(12,1488))
    
    SST_radfit = xr.DataArray(np.zeros((88,179)), dims=['lat','lon'])
    lat_index = 0
    for lat in rad_dataset_yearly.coords['lat'].values:
        lon_index = 0
        for lon in rad_dataset_yearly.coords['lon'].values:
            SST_slice = sst_dataset_yearly.sel(lat=lat).sel(lon=lon)
            rad_slice = rad_dataset_yearly.sel(lat=lat).sel(lon=lon)
            SST_radfit[lat_index, lon_index] = np.polyfit(SST_slice, rad_slice, deg=1)[0]     
            lon_index += 1
        lat_index += 1

    SST_radfit.coords['lon'] = rad_dataset_yearly['lon'].values
    SST_radfit.coords['lat'] = rad_dataset_yearly['lat'].values
    SST_radfit
    return SST_radfit

# %% [markdown]
# # Surface

# %%
sst_surface_fit = yearly_fit(SST, surface)
sst_surface_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[0.29590831, 0.29625423, 0.29783767, ..., 0.30167349, 0.30354256,
#         0.30176063],
#        [0.29729308, 0.2994858 , 0.30195089, ..., 0.30076909, 0.3022517 ,
#         0.29717301],
#        [0.28987432, 0.29011253, 0.29165393, ..., 0.28989522, 0.29283621,
#         0.29069138],
#        ...,
#        [0.77006204, 0.80651645, 0.83199443, ..., 0.56546522, 0.62858485,
#         0.68353324],
#        [0.50879854, 0.53616997, 0.57745669, ..., 0.36724772, 0.40266624,
#         0.4364854 ],
#        [0.44876336, 0.45666436, 0.46024395, ..., 0.36654736, 0.38777657,
#         0.4198316 ]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_surface_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-1, vmax=1)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean TS and Surface Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean TS and Surface Radiation')

# %%
tas_surface_fit = yearly_fit(TAS, surface)
tas_surface_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[0.29793965, 0.3001155 , 0.30165826, ..., 0.3032298 , 0.30803159,
#         0.30299166],
#        [0.29738349, 0.29903546, 0.30198979, ..., 0.29966967, 0.30171197,
#         0.29769282],
#        [0.28193377, 0.28018626, 0.28399041, ..., 0.28169554, 0.28486723,
#         0.28197822],
#        ...,
#        [0.77867256, 0.81390068, 0.83796137, ..., 0.57363832, 0.63774949,
#         0.69273863],
#        [0.51776405, 0.54500087, 0.58613739, ..., 0.37550149, 0.4116913 ,
#         0.44610013],
#        [0.45583163, 0.46378764, 0.46737581, ..., 0.37300234, 0.3943554 ,
#         0.42674663]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_surface_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-10, vmax=10)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean TAS and Surface Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean TAS and Surface Radiation')

# %% [markdown]
# # TOA

# %%
sst_toa_fit = yearly_fit(SST, TOA)
sst_toa_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-1.62505126, -1.55576043, -1.564823  , ..., -1.65078702,
#         -1.54070051, -1.62263965],
#        [-1.58128531, -1.59798158, -1.59152101, ..., -1.64456204,
#         -1.65220105, -1.59804005],
#        [-1.32608239, -1.40403685, -1.35720876, ..., -1.3383153 ,
#         -1.30339696, -1.36179942],
#        ...,
#        [-0.56318036, -0.51971125, -0.48562408, ..., -0.83565824,
#         -0.76631098, -0.69165097],
#        [-0.68260758, -0.64751595, -0.61945246, ..., -0.82501071,
#         -0.77849933, -0.74037871],
#        [-0.59803864, -0.58110197, -0.56367464, ..., -0.68625429,
#         -0.66254199, -0.63482437]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_toa_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-10, vmax=10)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean SST and TOA Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean SST and TOA Radiation')

# %%
tas_toa_fit = yearly_fit(TAS, TOA)
tas_toa_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[-1.63298086, -1.56669125, -1.56146915, ..., -1.650625  ,
#         -1.55111342, -1.64014123],
#        [-1.58013213, -1.59177147, -1.5808779 , ..., -1.63741299,
#         -1.645062  , -1.58582088],
#        [-1.27718571, -1.34750964, -1.31504282, ..., -1.28789578,
#         -1.25889886, -1.30621757],
#        ...,
#        [-0.60653947, -0.56403544, -0.53181427, ..., -0.88456871,
#         -0.81282742, -0.73602869],
#        [-0.72528788, -0.68887394, -0.6602797 , ..., -0.87315655,
#         -0.8244488 , -0.78546604],
#        [-0.64090412, -0.62362464, -0.60562308, ..., -0.72882481,
#         -0.70496418, -0.67745785]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_toa_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-10, vmax=10)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean TAS and TOA Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean TAS and TOA Radiation')

# %% [markdown]
# # Horiz

# %%
sst_horiz_fit = yearly_fit(SST, horiz)
sst_horiz_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[1.92095957, 1.85201466, 1.86266067, ..., 1.95246051, 1.84424306,
#         1.92440028],
#        [1.87857839, 1.89746738, 1.8934719 , ..., 1.94533112, 1.95445275,
#         1.89521307],
#        [1.61595671, 1.69414938, 1.64886269, ..., 1.62821052, 1.59623317,
#         1.65249079],
#        ...,
#        [1.3332424 , 1.3262277 , 1.31761851, ..., 1.40112346, 1.39489582,
#         1.37518421],
#        [1.19140611, 1.18368593, 1.19690915, ..., 1.19225844, 1.18116557,
#         1.1768641 ],
#        [1.046802  , 1.03776634, 1.0239186 , ..., 1.05280166, 1.05031856,
#         1.05465597]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
sst_horiz_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-10, vmax=10)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean TS and Horiz. Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean TS and Horiz. Radiation')

# %%
tas_horiz_fit = yearly_fit(TAS, horiz)
tas_horiz_fit
# Out:
# <xarray.DataArray (lat: 88, lon: 179)>
# array([[1.93092051, 1.86680676, 1.86312741, ..., 1.9538548 , 1.85914502,
#         1.94313289],
#        [1.87751562, 1.89080693, 1.88286769, ..., 1.93708266, 1.94677396,
#         1.8835137 ],
#        [1.55911948, 1.6276959 , 1.59903324, ..., 1.56959132, 1.5437661 ,
#         1.58819579],
#        ...,
#        [1.38521203, 1.37793612, 1.36977563, ..., 1.45820703, 1.4505769 ,
#         1.42876732],
#        [1.24305193, 1.23387481, 1.24641709, ..., 1.24865804, 1.23614011,
#         1.23156618],
#        [1.09673575, 1.08741229, 1.07299889, ..., 1.10182715, 1.09931958,
#         1.10420448]])
# Coordinates:
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -87 -85 -83 -81 -79 -77 -75 ... 75 77 79 81 83 85 87

# %%
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
tas_horiz_fit.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='RdBu_r', vmin=-10, vmax=10)
ax.coastlines(color='black', linewidth=1)
plt.title('Yearly Regression of Slab Ocean TAS and Horiz. Radiation')
# Out:
# Text(0.5, 1.0, 'Yearly Regression of Slab Ocean TAS and Horiz. Radiation')
